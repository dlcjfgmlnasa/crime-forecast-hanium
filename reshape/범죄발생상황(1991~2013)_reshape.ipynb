# %%
import pandas as pd
import os

# %%
포맷안된파일='C:/Users/chlee/Desktop/crime-forecast-hanium/포맷안된파일'
타겟파일='C:/Users/chlee/Desktop/crime-forecast-hanium/데이터파일'
파일이름='범죄 발생상황[1964-2013].xlsx'

# %%
데이터프레임=pd.read_excel(os.path.join(포맷안된파일,파일이름))
데이터프레임
# Out:
#      범죄명칭  Unnamed: 1           Unnamed: 2 Unnamed: 3     1991 Unnamed: 5  \
# 0     NaN         NaN                  NaN        NaN     발생건수        NaN
# 1     NaN         NaN                  NaN        NaN       1월         2월
# 2     NaN         NaN                  NaN        NaN  1991년1월    1991년2월
# 3    강력범죄          강도                  NaN        NaN      273        264
# 4     NaN     기타_강력범죄        총포.도검.화약류등단속법        NaN      393        161
# 5     NaN          방화                   방화        NaN       66         96
# 6     NaN         NaN                   실화        NaN      380        364
# 7     NaN          살인                  NaN        NaN       42         37
# 8    경제범죄        금융범죄  대부업등의등록및금융이용자보호에관한법        NaN      NaN        NaN
# 9     NaN         NaN                대외무역법        NaN        1          1
# 10    NaN         NaN              부정수표단속법        NaN     2752       2702
# 11    NaN         NaN              상호신용금고법        NaN      NaN        NaN
# ...

# %%
범죄대분류리스트=[범죄 for 범죄 in 데이터프레임['범죄명칭'].values.tolist() ]
Temp=''
for i,범죄 in enumerate(범죄대분류리스트) :
    if pd.notnull(범죄) :
        Temp=범죄
    범죄대분류리스트[i]=Temp
범죄대분류리스트=list(filter(lambda x : x != '', 범죄대분류리스트))
범죄대분류리스트
# Out:
# ['강력범죄',
#  '강력범죄',
#  '강력범죄',
#  '강력범죄',
#  '강력범죄',
#  '경제범죄',
#  '경제범죄',
#  '경제범죄',
#  '경제범죄',
#  '경제범죄',
#  '경제범죄',
#  '경제범죄',
#  '경제범죄',
#  '경제범죄',
#  '경제범죄',
#  '경제범죄',
#  '경제범죄',
#  '경제범죄',
#  '경제범죄',
#  '경제범죄',
#  '경제범죄',
#  '경제범죄',
#  '경제범죄',
#  '경제범죄',
#  '경제범죄',
#  '경제범죄',
#  '경제범죄',
#  '경제범죄',
#  '경제범죄',
#  '경제범죄',
#  '경제범죄',
#  '경제범죄',
#  '경제범죄',
#  '경제범죄',
#  '경제범죄',
#  '경제범죄',
#  '경제범죄',
#  '경제범죄',
#  '경제범죄',
#  '경제범죄',
#  '공무원범죄',
#  '공무원범죄',
#  '공무원범죄',
#  '공무원범죄',
#  '공무원범죄',
#  '공무집행방해범죄',
#  '공무집행방해범죄',
#  '공무집행방해범죄',
#  '공무집행방해범죄',
#  '공안범죄',
#  '공안범죄',
#  '공안범죄',
#  '공안범죄',
#  '공안범죄',
#  '공안범죄',
#  '공안범죄',
#  '공안범죄',
#  '공안범죄',
#  '공안범죄',
#  '공안범죄',
#  '공안범죄',
#  '공안범죄',
#  '공안범죄',
#  '공안범죄',
#  '공안범죄',
#  '과실치사상죄',
#  '과실치사상죄',
#  '교통범죄',
#  '교통범죄',
#  '교통범죄',
#  '교통범죄',
#  '교통범죄',
#  '교통범죄',
#  '교통범죄',
#  '교통범죄',
#  '교통범죄',
#  '교통범죄',
#  '교통범죄',
#  '교통범죄',
#  '교통범죄',
#  '교통범죄',
#  '군사범죄',
#  '군사범죄',
#  '군사범죄',
#  '군사범죄',
#  '기타_범죄',
#  '기타_범죄',
#  '기타_범죄',
# ...

# %%
범죄소분류리스트=[범죄 for 범죄 in 데이터프레임['Unnamed: 1'].values.tolist()]
Temp=''
for i,범죄 in enumerate(범죄소분류리스트) :
    if pd.notnull(범죄) :
        Temp=범죄
    범죄소분류리스트[i]=Temp
범죄소분류리스트=list(filter(lambda x : x != '', 범죄소분류리스트))
범죄소분류리스트
# Out:
# ['강도',
#  '기타_강력범죄',
#  '방화',
#  '방화',
#  '살인',
#  '금융범죄',
#  '금융범죄',
#  '금융범죄',
#  '금융범죄',
#  '금융범죄',
#  '금융범죄',
#  '금융범죄',
#  '금융범죄',
#  '금융범죄',
#  '금융범죄',
#  '기타_경제범죄',
#  '기타_경제범죄',
#  '기타_경제범죄',
#  '기타_경제범죄',
#  '기타_경제범죄',
#  '보험범죄',
#  '보험범죄',
#  '보험범죄',
#  '보험범죄',
#  '보험범죄',
#  '불공정거래',
#  '불공정거래',
#  '불공정거래',
#  '조세범죄',
#  '조세범죄',
#  '조세범죄',
#  '조세범죄',
#  '지적재산권등침해범죄',
#  '지적재산권등침해범죄',
#  '지적재산권등침해범죄',
#  '지적재산권등침해범죄',
#  '지적재산권등침해범죄',
#  '지적재산권등침해범죄',
#  '지적재산권등침해범죄',
#  '지적재산권등침해범죄',
#  '뇌물범죄',
#  '뇌물범죄',
#  '뇌물범죄',
#  '직무범죄',
#  '직무범죄',
#  '공무집행방해',
#  '도주_범인은닉',
#  '무고범죄',
#  '위증_증거인멸',
#  '국가보안법',
#  '국가보안법',
#  '기타_공안범죄',
#  '기타_공안범죄',
#  '내란',
#  '범죄단체구성등',
#  '선거정당',
#  '선거정당',
#  '선거정당',
#  '선거정당',
#  '선거정당',
#  '집회및시위',
#  '집회및시위',
#  '출입국',
#  '출입국',
#  '출입국',
#  '과실치사상',
#  '과실치사상',
#  '도로교통',
#  '도로교통',
#  '도로교통',
#  '도로교통',
#  '도로교통',
#  '도로교통',
#  '도로교통',
#  '도로교통',
#  '도로교통',
#  '해상교통',
#  '해상교통',
#  '해상교통',
#  '해상교통',
#  '해상교통',
#  '기타_군사범죄',
#  '기타_군사범죄',
# ...

# %%
인덱스리스트=[]
for index in 데이터프레임.index :
    word=''
    for column in ['Unnamed: 2','Unnamed: 3'] :
        Temp=데이터프레임.ix[index][column]
        if pd.notnull(Temp) : word+=Temp+','
    if word == '' : word=데이터프레임.ix[index]['Unnamed: 1']
    else : word=word[:-1]
    인덱스리스트.append(word)
인덱스리스트=list(filter(lambda x : pd.notnull(x), 인덱스리스트))
인덱스리스트
# Out:
# ['강도',
#  '총포.도검.화약류등단속법',
#  '방화',
#  '실화',
#  '살인',
#  '대부업등의등록및금융이용자보호에관한법',
#  '대외무역법',
#  '부정수표단속법',
#  '상호신용금고법',
#  '신용정보의이용및보호에관한법률',
#  '신용카드업법',
#  '여신전문금융업법',
#  '외국환거래법',
#  '증권거래법',
#  '특정경제범죄의가중처벌에관한법률',
#  '기부금품모집금지법',
#  '물가안정에관한법률',
#  '부동산실권리자명의등기에관한법률',
#  '우편법',
#  '우편법(우편법및임시우편단속법)',
#  '고용보험법',
#  '국민연금법',
#  '산업재해보상보험법',
#  '자동차손해배상보장법',
#  '화재보험위반',
#  '독점규제및공정거래에관한법률',
#  '방문판매등에관한법률',
#  '신용,업무,경매에 관한 죄',
#  '관세법',
#  '범죄수익은닉의규제및처벌등에관한법률',
#  '조세범처벌법',
#  '지방세법',
#  '디자인보호법',
#  '부정경쟁방지및영업비밀보호에관한법률',
#  '상법',
#  '상표법',
#  '실용신안법',
#  '저작권법',
#  '컴퓨터프로그램보호법',
#  '특허법',
#  '뇌물',
#  '수뢰',
#  '증뢰',
#  '직권남용',
#  '직무유기',
#  '공무방해',
#  '도주와 범인은닉에 관한 죄',
#  '무고',
#  '위증과 증거인멸에 관한 죄',
#  '국가보안법',
#  '반공법',
#  '공안을해하는죄',
#  '전기통신기본법',
#  '내란의죄',
#  '폭처법(단체등의구성,활동)',
#  '공직선거법',
#  '국회의원선거법',
#  '대통령선거법',
#  '정당법',
#  '정치자금에관한법률',
#  '집회및시위에관한법률',
#  '화염병사용등의처벌에관한법률',
#  '밀항단속법',
#  '여권법',
#  '출입국관리법',
#  '과실치사상',
#  '업무상과실치사상',
#  '교통방해',
#  '교통사고처리특례법',
#  '도로교통법',
# ...

# %%
데이터프레임=데이터프레임.drop(['범죄명칭','Unnamed: 1','Unnamed: 2','Unnamed: 3'],axis=1)
데이터프레임
# Out:
#         1991 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 0       발생건수        NaN        NaN        NaN        NaN        NaN
# 1         1월         2월         3월         4월         5월         6월
# 2    1991년1월    1991년2월    1991년3월    1991년4월    1991년5월    1991년6월
# 3        273        264        263        242        194        267
# 4        393        161        130         74         39         71
# 5         66         96         81        110         82         81
# 6        380        364        414        433        370        330
# 7         42         37         54         49         56         56
# 8        NaN        NaN        NaN        NaN        NaN        NaN
# 9          1          1          2          7          4          6
# 10      2752       2702       3415       2907       2812       3279
# 11       NaN        NaN        NaN        NaN        NaN        NaN
# 12       NaN        NaN        NaN        NaN        NaN        NaN
# ...

# %%
데이터프레임리스트={year:[] for year in range(1991,2014)}
Temp
for 콜론 in 데이터프레임 :
    try : Temp=int(콜론)
    except : pass
    데이터프레임리스트[Temp].append(데이터프레임[콜론])

# %%
for 년도, 데이터프레임 in 데이터프레임리스트.items() :
    데이터프레임=pd.concat(데이터프레임,axis=1)
    콜론인덱스=[column for column in 데이터프레임.ix[1].values.tolist()]
    데이터프레임.columns = 콜론인덱스
    데이터프레임=데이터프레임.drop([0,1,2])
    데이터프레임=데이터프레임.set_index([인덱스리스트])
    데이터프레임.insert(0,value=범죄대분류리스트,column='범죄대분류')
    데이터프레임.insert(1,value=범죄소분류리스트,column='범죄소분류')
    데이터프레임=데이터프레임.T
    데이터프레임리스트[년도]=데이터프레임

# %%
writer=pd.Excel
for 년도, 데이터프레임 in 데이터프레임리스트.items() :
# Out:
#          강도 총포.도검.화약류등단속법    방화    실화    살인 대부업등의등록및금융이용자보호에관한법 대외무역법 부정수표단속법  \
# 범죄대분류  강력범죄          강력범죄  강력범죄  강력범죄  강력범죄                경제범죄  경제범죄    경제범죄
# 범죄소분류    강도       기타_강력범죄    방화    방화    살인                금융범죄  금융범죄    금융범죄
# 1월      273           393    66   380    42                 NaN     1    2752
# 2월      264           161    96   364    37                 NaN     1    2702
# 3월      263           130    81   414    54                 NaN     2    3415
# 4월      242            74   110   433    49                 NaN     7    2907
# 5월      194            39    82   370    56                 NaN     4    2812
# 6월      267            71    81   330    56                 NaN     6    3279
# 7월      241            36    73   192    54                 NaN     6    2859
# 8월      238            29    66   219    69                 NaN     2    2819
# 9월      222            26    87   223    53                 NaN     3    3027
# ...
